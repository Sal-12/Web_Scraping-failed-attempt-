# %%
from bs4 import BeautifulSoup

# %%
import requests
import time
import urllib.request

# %%
url = 'http://web.mta.info/developers/turnstile.html'
response = requests.get(url)

# %%
response  # means it went through
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
soup.findAll('a')
# Out:
# [<a href="#main-content">Skip to main content</a>,
#  <a href="http://www.mta.info"><img alt="To MTA.info homepage" src="/template/images/mta_info.gif"/></a>,
#  <a href="/accessibility">Accessibility</a>,
#  <a href="http://assistive.usablenet.com/tt/http://www.mta.info">Text-only</a>,
#  <a href="/selfserve">Customer Self-Service</a>,
#  <a href="/mta/employment/">Employment</a>,
#  <a href="/faqs.htm">FAQs/Contact Us</a>,
#  <a href="https://new.mta.info/coronavirus" style="text-decoration: none;color: yellow !important;" target="_blank">Read more</a>,
#  <a href="http://www.mta.info" style="padding-left:18px;">Home</a>,
#  <a href="http://www.mta.info">MTA Home</a>,
#  <a href="http://www.mta.info/nyct">NYC Subways and Buses</a>,
#  <a href="http://www.mta.info/lirr">Long Island Rail Road</a>,
#  <a href="http://www.mta.info/mnr">Metro-North Railroad</a>,
#  <a href="http://www.mta.info/bandt">Bridges and Tunnels</a>,
# ...

# %%
one_a_tag = soup.findAll('a')[38]
link = one_a_tag['href']

# %%
download_url = 'http://web.mta.info/developers/'+ link
urllib.request.urlretrieve(download_url,'./'+link[link.find('/turnstile_')+1:])
# Out:
# ('./turnstile_210515.txt', <http.client.HTTPMessage at 0x29d8817d6c8>)

# %%
time.sleep(1)

# %%
line_count = 1
for one_a_tag in soup.findAll('a'): #'a' tags are for links
    if line_count >= 36: #code for text files starts at line 36
        link = one_a_tag['href']
        download_url = 'http://web.mta.info/developers/'+ link
        urllib.request.urlretrieve(download_url,'./'+link[link.find('/turnstile_')+1:]) 
        time.sleep(1)
    line_count +=1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-cc1e57936eac> in <module>
#       4         link = one_a_tag['href']
#       5         download_url = 'http://web.mta.info/developers/'+ link
# ----> 6         urllib.request.urlretrieve(download_url,'./'+link[link.find('/turnstile_')+1:])
#       7         time.sleep(1)
#       8     line_count +=1
#
# ~\Anaconda3\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     255         # Handle temporary file setup.
#     256         if filename:
# --> 257             tfp = open(filename, 'wb')
#     258         else:
#     259             tfp = tempfile.NamedTemporaryFile(delete=False)
#
# FileNotFoundError: [Errno 2] No such file or directory: './resources/nyct/turnstile/ts_Field_Description.txt'

# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup

# %%
url = 'http://web.mta.info/developers/turnstile.html'

# %%
response = requests.get(url)

# %%
response #200 means it went through
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
#
# <html lang="en">
# <head>
# <title>mta.info | Turnstile Data</title>
# <meta content="noindex" name="robots"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!--<meta http-equiv="X-UA-Compatible" content="IE=EmulateIE7">-->
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="/siteimages/favicon.ico" rel="shortcut icon"/>
# <link href="/css/base.css" rel="stylesheet" type="text/css"/>
# <link href="/css/grid.css" rel="stylesheet" type="text/css"/>
# <link href="/css/topbar.css" rel="stylesheet" type="text/css"/>
# <link href="/css/formalize.css" rel="stylesheet" type="text/css"/>
# <!-- <link rel="stylesheet" type="text/css" href="/css/jquery.datepick.css"> -->
# <!-- jQuery include should be at the top -->
# ...

# %%
soup.findAll('a')
# Out:
# [<a href="#main-content">Skip to main content</a>,
#  <a href="http://www.mta.info"><img alt="To MTA.info homepage" src="/template/images/mta_info.gif"/></a>,
#  <a href="/accessibility">Accessibility</a>,
#  <a href="http://assistive.usablenet.com/tt/http://www.mta.info">Text-only</a>,
#  <a href="/selfserve">Customer Self-Service</a>,
#  <a href="/mta/employment/">Employment</a>,
#  <a href="/faqs.htm">FAQs/Contact Us</a>,
#  <a href="https://new.mta.info/coronavirus" style="text-decoration: none;color: yellow !important;" target="_blank">Read more</a>,
#  <a href="http://www.mta.info" style="padding-left:18px;">Home</a>,
#  <a href="http://www.mta.info">MTA Home</a>,
#  <a href="http://www.mta.info/nyct">NYC Subways and Buses</a>,
#  <a href="http://www.mta.info/lirr">Long Island Rail Road</a>,
#  <a href="http://www.mta.info/mnr">Metro-North Railroad</a>,
#  <a href="http://www.mta.info/bandt">Bridges and Tunnels</a>,
# ...

# %%
one_a_tag = soup.findAll('a')[36]

# %%
link = one_a_tag['href']
link
# Out:
# 'resources/nyct/turnstile/Remote-Booth-Station.xls'

# %%
line_count = 1
for one_a_tag in soup.findAll('a'): #'a' tags are for links
    if line_count >= 36: #code for text files starts at line 36
        link = one_a_tag['href']
        download_url = 'http://web.mta.info/developers/'+ link
        urllib.request.urlretrieve(download_url,'./'+link[link.find('/turnstile_')+1:]) 
        time.sleep(1)
    line_count +=1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-cc1e57936eac> in <module>
#       4         link = one_a_tag['href']
#       5         download_url = 'http://web.mta.info/developers/'+ link
# ----> 6         urllib.request.urlretrieve(download_url,'./'+link[link.find('/turnstile_')+1:])
#       7         time.sleep(1)
#       8     line_count +=1
#
# ~\Anaconda3\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     255         # Handle temporary file setup.
#     256         if filename:
# --> 257             tfp = open(filename, 'wb')
#     258         else:
#     259             tfp = tempfile.NamedTemporaryFile(delete=False)
#
# FileNotFoundError: [Errno 2] No such file or directory: './resources/nyct/turnstile/ts_Field_Description.txt'

# %%
import bs4 as bs

# %%
import urllib.request
source = urllib.request.urlopen('https://pythonprogramming.net/parsememcparseface/').read()
soup = bs.BeautifulSoup(source, 'lxml')

# %%
import lxml

# %%
soup = bs.BeautifulSoup(source, 'lxml')
soup
# Out:
# <html>
# <head>
# <!--
# 		palette:
# 		dark blue: #003F72
# 		yellow: #FFD166
# 		salmon: #EF476F
# 		offwhite: #e7d7d7
# 		Light Blue: #118AB2
# 		Light green: #7DDF64
# 		-->
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Python Programming Tutorials</title>
# <meta content="Python Programming tutorials from beginner to advanced on a massive variety of topics. All video and text tutorials are free." name="description"/>
# <link href="/static/favicon.ico" rel="shortcut icon"/>
# <link href="/static/css/materialize.min.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <meta content="3fLok05gk5gGtWd_VSXbSSSH27F2kr1QqcxYz9vYq2k" name="google-site-verification"/>
# <link href="/static/css/bootstrap.css" rel="stylesheet" type="text/css"/>
# <!-- Compiled and minified CSS -->
# <!-- Compiled and minified JavaScript -->
# ...

# %%
print(soup.title) # gets title
# Out:
# <title>Python Programming Tutorials</title>

# %%
print(soup.title.name)
# Out:
# title

# %%
print(response)
# Out:
# <Response [200]>

# %%
print(soup.title.string)
# Out:
# Python Programming Tutorials

# %%
print(soup.title.text)
# Out:
# Python Programming Tutorials

# %%
soup.p   # first paragragh introduction
# Out:
# <p class="introduction">Oh, hello! This is a <span style="font-size:115%">wonderful</span> page meant to let you practice web scraping. This page was originally created to help people work with the <a href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/" target="blank"><strong>Beautiful Soup 4</strong></a> library.</p>

# %%
soup.find_all('span')
# Out:
# [<span style="font-size:115%">wonderful</span>]

# %%
for paragraph in soup.find_all('p'):
    print(paragraph)
# Out:
# <p class="introduction">Oh, hello! This is a <span style="font-size:115%">wonderful</span> page meant to let you practice web scraping. This page was originally created to help people work with the <a href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/" target="blank"><strong>Beautiful Soup 4</strong></a> library.</p>
# <p>The following table gives some general information for the following <code>programming languages</code>:</p>
# <p>I think it's clear that, on a scale of 1-10, python is:</p>
# <p>Javascript (dynamic data) test:</p>
# <p class="jstest" id="yesnojs">y u bad tho?</p>
# <p>Whᶐt hαppéns now¿</p>
# <p><a href="/sitemap.xml" target="blank"><strong>sitemap</strong></a></p>
# <p class="grey-text text-lighten-4">Contact: Harrison@pythonprogramming.net.</p>
# <p class="grey-text right" style="padding-right:10px">Programming is a superpower.</p>

# %%
paragraph.string # .string is navigable string
# Out:
# 'Programming is a superpower.'

# %%
paragraph.text # returns everythings
# Out:
# 'Programming is a superpower.'

# %%
print(soup.get_text())
# Out:
# Python Programming Tutorials
#
#
#
#
#
#
#
#
#
#
#
# 		@media (min-width:992px) {
# 		#aside {
# 			width:250px;
# 		}
# 		pre { tab-size: 4;}
# 		.btn {background-color:#FFD166;
# 			  color:#000;
# 		      height:auto;
# 			  font-color:#000;
# 			  }
# 		.btn:hover {background-color:#FFD166;
# 					}
#
#
#
#
#
# 			  (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 			  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 			  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 			  })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#               ga('config', 'UA-51891827-1', {'anonymize_ip': true});﻿
# 			  ga('create', 'UA-51891827-1', 'auto');
# 			  ga('send', 'pageview');
#
#
#
#
#                          (adsbygoogle = window.adsbygoogle || []).push({
#                               google_ad_client: "ca-pub-1579050400541873",
# ...

# %%
for url in soup.find_all('a'):
    print(url.get('href'))
# Out:
# /
# #
# /
# /+=1/
# /support/
# https://goo.gl/7zgAVQ
# /login/
# /register/
# /
# /+=1/
# /support/
# https://goo.gl/7zgAVQ
# /login/
# /register/
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/
# /sitemap.xml
# /support-donate/
# /consulting/
# https://www.facebook.com/pythonprogramming.net/
# https://twitter.com/sentdex
# https://instagram.com/sentdex
# /about/tos/
# /about/privacy-policy/
# https://xkcd.com/353/

# %%
#for url in soup.find_all('')
nav = soup.nav

# %%
nav
# Out:
# <nav style="background-color:#003F72">
# <div class="nav-wrapper container">
# <a class="brand-logo" href="/"><img class="img-responsive" src="/static/images/mainlogowhitethick.jpg" style="width:50px; height;50px; margin-top:5px"/></a>
# <a class="button-collapse" data-activates="navsidebar" href="#"><i class="mdi-navigation-menu"></i></a>
# <ul class="right hide-on-med-and-down">
# <li><i class="material-icons">search</i></li>
# <li>
# <form action="/search/?l=hi" id="searchform" method="get" style="height:50px; padding-top:10px">
# <input id="search" name="q" placeholder="search" style="font-size:16px" type="search"/>
# </form>
# </li>
# <li><a href="/">Home</a></li>
# <li><a class="tooltipped" data-delay="50" data-position="bottom" data-tooltip="sudo apt-get upgrade" href="/+=1/">+=1</a></li>
# <!--<li><a href="/store/python-hoodie/">Store</a></li>-->
# <li><a href="/support/">Support the Content</a></li>
# ...

# %%
for url in nav.find_all('a'):
    print(url.get('href'))
# Out:
# /
# #
# /
# /+=1/
# /support/
# https://goo.gl/7zgAVQ
# /login/
# /register/
# /
# /+=1/
# /support/
# https://goo.gl/7zgAVQ
# /login/
# /register/

# %%
body = soup.body
for paragraph in body.find_all('p'):
    print(paragraph.text)
# Out:
# Oh, hello! This is a wonderful page meant to let you practice web scraping. This page was originally created to help people work with the Beautiful Soup 4 library.
# The following table gives some general information for the following programming languages:
# I think it's clear that, on a scale of 1-10, python is:
# Javascript (dynamic data) test:
# y u bad tho?
# Whᶐt hαppéns now¿
# sitemap

# %%
for div in soup.find_all('div'):
    print(div.text)
# Out:
# search
#
#
#
#
#
# Home
# +=1
#
# Support the Content
# Community
# Log in
# Sign up
#
#
#
#
#
#
#
# Home
# +=1
#
# Support the Content
# Community
# Log in
# Sign up
#
#
#
#
#
#
#
#
# search
#
#
#
#
#
# Home
# +=1
#
# Support the Content
# Community
# Log in
# Sign up
#
#
#
#
#
#
#
# Home
# +=1
#
# Support the Content
# Community
# Log in
# Sign up
#
#
#
#
#
#
#
# Oh, hello! This is a wonderful page meant to let you practice web scraping. This page was originally created to help people work with the Beautiful Soup 4 library.
# The following table gives some general information for the following programming languages:
#
# Python
# Pascal
# Lisp
# D#
# Cobol
# Fortran
# Haskell
#
#
#
# Program Name
# Internet Points
# Kittens?
#
#
# Python
# 932914021
# Definitely
#
#
# Pascal
# 532
# Unlikely
#
#
# Lisp
# 1522
# Uncertain
#
#
# D#
# 12
# Possibly
#
#
# Cobol
# 3
# No.
#
#
# Fortran
# 52124
# Yes.
#
#
# Haskell
# 24
# lol.
#
#
# I think it's clear that, on a scale of 1-10, python is:
# ...

# %%
for div in soup.find_all('div', class_='body'):
    print(div.text)
# Out:
# Oh, hello! This is a wonderful page meant to let you practice web scraping. This page was originally created to help people work with the Beautiful Soup 4 library.
# The following table gives some general information for the following programming languages:
#
# Python
# Pascal
# Lisp
# D#
# Cobol
# Fortran
# Haskell
#
#
#
# Program Name
# Internet Points
# Kittens?
#
#
# Python
# 932914021
# Definitely
#
#
# Pascal
# 532
# Unlikely
#
#
# Lisp
# 1522
# Uncertain
#
#
# D#
# 12
# Possibly
#
#
# Cobol
# 3
# No.
#
#
# Fortran
# 52124
# Yes.
#
#
# Haskell
# 24
# lol.
#
#
# I think it's clear that, on a scale of 1-10, python is:
#
#
#
#
#
#
# Javascript (dynamic data) test:
# y u bad tho?
#
#      document.getElementById('yesnojs').innerHTML = 'Look at you shinin!';
#
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# ...

# %%
table = soup.table

print(table)
# Out:
# <table style="width:100%">
# <tr>
# <th>Program Name</th>
# <th>Internet Points</th>
# <th>Kittens?</th>
# </tr>
# <tr>
# <td>Python</td>
# <td>932914021</td>
# <td>Definitely</td>
# </tr>
# <tr>
# <td>Pascal</td>
# <td>532</td>
# <td>Unlikely</td>
# </tr>
# <tr>
# <td>Lisp</td>
# <td>1522</td>
# <td>Uncertain</td>
# </tr>
# <tr>
# <td>D#</td>
# <td>12</td>
# <td>Possibly</td>
# </tr>
# <tr>
# <td>Cobol</td>
# <td>3</td>
# <td>No.</td>
# </tr>
# <tr>
# <td>Fortran</td>
# <td>52124</td>
# <td>Yes.</td>
# </tr>
# <tr>
# <td>Haskell</td>
# <td>24</td>
# <td>lol.</td>
# </tr>
# </table>

# %%
table = soup.find('table')
print(table)
# Out:
# <table style="width:100%">
# <tr>
# <th>Program Name</th>
# <th>Internet Points</th>
# <th>Kittens?</th>
# </tr>
# <tr>
# <td>Python</td>
# <td>932914021</td>
# <td>Definitely</td>
# </tr>
# <tr>
# <td>Pascal</td>
# <td>532</td>
# <td>Unlikely</td>
# </tr>
# <tr>
# <td>Lisp</td>
# <td>1522</td>
# <td>Uncertain</td>
# </tr>
# <tr>
# <td>D#</td>
# <td>12</td>
# <td>Possibly</td>
# </tr>
# <tr>
# <td>Cobol</td>
# <td>3</td>
# <td>No.</td>
# </tr>
# <tr>
# <td>Fortran</td>
# <td>52124</td>
# <td>Yes.</td>
# </tr>
# <tr>
# <td>Haskell</td>
# <td>24</td>
# <td>lol.</td>
# </tr>
# </table>

# %%
table_rows = table.find_all('tr')

for tr in table_rows:
    td = tr.find_all('td')
    row = [i.text for i in td]
    print(row)
# Out:
# []
# ['Python', '932914021', 'Definitely']
# ['Pascal', '532', 'Unlikely']
# ['Lisp', '1522', 'Uncertain']
# ['D#', '12', 'Possibly']
# ['Cobol', '3', 'No.']
# ['Fortran', '52124', 'Yes.']
# ['Haskell', '24', 'lol.']

# %%
table_columns = table.find_all('tc')

for tc in table_columns:
    tC = tr.find_all ('tC')
    column = [j.text for j in tC]
    print(column)

# %%
# pandas

import pandas as pd

dfs = pd.read_html('https://pythonprogramming.net/parsememcparseface/',header=0)

for df in dfs:
    print(df)
# Out:
#   Program Name  Internet Points    Kittens?
# 0       Python        932914021  Definitely
# 1       Pascal              532    Unlikely
# 2         Lisp             1522   Uncertain
# 3           D#               12    Possibly
# 4        Cobol                3         No.
# 5      Fortran            52124        Yes.
# 6      Haskell               24        lol.

# %%
source1 = urllib.request.urlopen('https://pythonprogramming.net/sitemap.xml').read()
soup = bs.BeautifulSoup(source1, 'xml')

# %%
soup
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <urlset xmlns="http://www.sitemaps.org/schemas/sitemap/0.9">
# <url>
# <loc>https://pythonprogramming.net/downloads/intraQuarter.zip/</loc>
# <lastmod>2021-05-20</lastmod>
# </url>
# <url>
# <loc>https://pythonprogramming.net/downloads/knowledgeBase.db</loc>
# <lastmod>2021-05-20</lastmod>
# </url>
# <url>
# <loc>https://pythonprogramming.net/downloads/key_stats.csv</loc>
# <lastmod>2021-05-20</lastmod>
# </url>
# <url>
# <loc>https://pythonprogramming.net/downloads/style.zip</loc>
# <lastmod>2021-05-20</lastmod>
# </url>
# <url>
# <loc>https://pythonprogramming.net/community/post/</loc>
# <lastmod>2021-05-20</lastmod>
# </url>
# <url>
# <loc>https://pythonprogramming.net/NVIDIA/GameGAN.pdf</loc>
# <lastmod>2021-05-20</lastmod>
# </url>
# <url>
# <loc>https://pythonprogramming.net/about/privacy-policy/</loc>
# <lastmod>2021-05-20</lastmod>
# </url>
# <url>
# <loc>https://pythonprogramming.net/store/python-hoodie/</loc>
# ...

# %%
for url in soup.find_all('loc'):
    print(url.text)
# Out:
# https://pythonprogramming.net/downloads/intraQuarter.zip/
# https://pythonprogramming.net/downloads/knowledgeBase.db
# https://pythonprogramming.net/downloads/key_stats.csv
# https://pythonprogramming.net/downloads/style.zip
# https://pythonprogramming.net/community/post/
# https://pythonprogramming.net/NVIDIA/GameGAN.pdf
# https://pythonprogramming.net/about/privacy-policy/
# https://pythonprogramming.net/store/python-hoodie/
# https://pythonprogramming.net/about/super-powers/
# https://pythonprogramming.net/about/technology/
# https://pythonprogramming.net/about/tos/
# https://pythonprogramming.net/user/change-password/
# https://pythonprogramming.net/go/template-news-aggregator-go-language-programming-tutorial/
# https://pythonprogramming.net/go/looping-sitemap-data-go-language-programming-tutorial/
# https://pythonprogramming.net/go/channel-buffer-range-go-language-programming-tutorial/
# https://pythonprogramming.net/go/concurrency-web-app-go-language-programming-tutorial/
# ...

# %%
table = soup.table

# %%
table

# %%
import sys
import PyQt4.QtGui import QApplication
from PyQt4.QtCore import QUrl
from PyQt4.QtWebKit import QWebPage
# Out:
#   File "<ipython-input-53-9cac531c21bd>", line 2
#     import PyQt4.QtGui import QApplication
#                             ^
# SyntaxError: invalid syntax

# %%
# Dynamic JavaScripting
source = urllib.request.urlopen('https://pythonprogramming.net/parsememcparseface/')
soup = bs.BeautifulSoup(source, 'lxml')
js_test = soup.find('p', class_='jstest')
print(js_test.text)
# Out:
# y u bad tho?

# %%
#pyQt

class Client(QWebPage):
    
    def __init__(self, url):
        QWebPage.__init__(self)
        self.loadFinished.connect(self.on_page_load)
     
    def on_page_load(self):
        self.app.quit()
        
        
url = 'https://pythonprogramming.net/parsememcparseface/'
client = Client(url)
source = client_response.mainFrame().toHtml()
# Dynamic JavaScripting
source = urllib.request.urlopen('https://pythonprogramming.net/parsememcparseface/')
soup = bs.BeautifulSoup(source, 'lxml')
js_test = soup.find('p', class_='jstest')
print(js_test.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-2e65a530796c> in <module>
#       1 #pyQt
#       2
# ----> 3 class Client(QWebPage):
#       4
#       5     def __init__(self, url):
#
# NameError: name 'QWebPage' is not defined

# %%
from bs4 import BeautifulSoup

# %%
import requests
import urllib.request

# %%
page = requests.get('https://forecast.weather.gov/MapClick.php?lat=41.884250000000065&lon=-87.63244999999995#.Xv6vaygzbIU')
soup = BeautifulSoup(page.content, 'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="no-js">
# <head>
# <!-- Meta -->
# <meta content="width=device-width" name="viewport"/>
# <link href="http://purl.org/dc/elements/1.1/" rel="schema.DC"/><title>National Weather Service</title><meta content="National Weather Service" name="DC.title"/><meta content="NOAA National Weather Service National Weather Service" name="DC.description"/><meta content="US Department of Commerce, NOAA, National Weather Service" name="DC.creator"/><meta content="" name="DC.date.created" scheme="ISO8601"/><meta content="EN-US" name="DC.language" scheme="DCTERMS.RFC1766"/><meta content="weather, National Weather Service" name="DC.keywords"/><meta content="NOAA's National Weather Service" name="DC.publisher"/><meta content="National Weather Service" name="DC.contributor"/><meta content="http://www.weather.gov/disclaimer.php" name="DC.rights"/><meta content="General" name="rating"/><meta content="index,follow" name="robots"/>
# <!-- Icons -->
# ...

# %%
import pandas

# %%
print(soup.find_all('a'))
# Out:
# [<a class="pull-left" href="http://www.noaa.gov" id="header-noaa"><img alt="National Oceanic and Atmospheric Administration" src="/css/images/header_noaa.png"/></a>, <a class="pull-left" href="http://www.weather.gov" id="header-nws"><img alt="National Weather Service" src="/css/images/header_nws.png"/></a>, <a class="pull-right" href="http://www.commerce.gov" id="header-doc"><img alt="United States Department of Commerce" src="/css/images/header_doc.png"/></a>, <a href="http://www.weather.gov">HOME</a>, <a class="dropdown-toggle" data-toggle="dropdown" href="http://www.weather.gov/forecastmaps">FORECAST <span class="caret"></span></a>, <a href="http://www.weather.gov">Local</a>, <a href="http://digital.weather.gov">Graphical</a>, <a href="http://www.aviationweather.gov/">Aviation</a>, <a href="http://www.weather.gov/marine">Marine</a>, <a href="http://water.weather.gov/ahps/">Rivers and Lakes</a>, <a href="http://www.nhc.noaa.gov/">Hurricanes</a>, <a href="http://www.spc.noaa.gov/">S
# ...

# %%
week = soup.find(id='seven-day-forecast-body')

# %%
week
# Out:
# <div class="panel-body" id="seven-day-forecast-body">
# <div id="seven-day-forecast-container"><ul class="list-unstyled" id="seven-day-forecast-list"><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">This<br/>Afternoon</p>
# ...

# %%
print(week.find_all('li'))
# Out:
# [<li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">This<br/>Afternoon</p>
# <p><img alt="This Afternoon: Scattered showers, then showers likely and possibly a thunderstorm after 4pm.  Mostly cloudy, with a high near 56. Northeast wind around 15 mph, with gusts as high as 30 mph.  Chance of precipitation is 70%. New rainfall amounts of less than a tenth of an inch, except higher amounts possible in thunderstorms. " class="forecast-icon" src="newimages/medium/shra70.png" title="This Afternoon: Scattered showers, then showers likely and possibly a thunderstorm after 4pm.  Mostly cloudy, with a high near 56. Northeast wind around 15 mph, with gusts as high as 30 mph.  Chance of precipitation is 70%. New rainfall amounts of less than a tenth of an inch, except higher amounts possible in thunderstorms. "/></p><p class="short-desc">Showers<br/>Likely</p><p class="temp temp-high">High: 56 °F</p></div></li>, <li class="forecast-tombstone">
# ...

# %%
items = (week.find_all(class_='tombstone-container'))
print(items)
# Out:
# [<div class="tombstone-container">
# <p class="period-name">This<br/>Afternoon</p>
# <p><img alt="This Afternoon: Scattered showers, then showers likely and possibly a thunderstorm after 4pm.  Mostly cloudy, with a high near 56. Northeast wind around 15 mph, with gusts as high as 30 mph.  Chance of precipitation is 70%. New rainfall amounts of less than a tenth of an inch, except higher amounts possible in thunderstorms. " class="forecast-icon" src="newimages/medium/shra70.png" title="This Afternoon: Scattered showers, then showers likely and possibly a thunderstorm after 4pm.  Mostly cloudy, with a high near 56. Northeast wind around 15 mph, with gusts as high as 30 mph.  Chance of precipitation is 70%. New rainfall amounts of less than a tenth of an inch, except higher amounts possible in thunderstorms. "/></p><p class="short-desc">Showers<br/>Likely</p><p class="temp temp-high">High: 56 °F</p></div>, <div class="tombstone-container">
# <p class="period-name">Tonight<br/><br/></p>
# ...

# %%
print(items[0])
# Out:
# <div class="tombstone-container">
# <p class="period-name">This<br/>Afternoon</p>
# <p><img alt="This Afternoon: Scattered showers, then showers likely and possibly a thunderstorm after 4pm.  Mostly cloudy, with a high near 56. Northeast wind around 15 mph, with gusts as high as 30 mph.  Chance of precipitation is 70%. New rainfall amounts of less than a tenth of an inch, except higher amounts possible in thunderstorms. " class="forecast-icon" src="newimages/medium/shra70.png" title="This Afternoon: Scattered showers, then showers likely and possibly a thunderstorm after 4pm.  Mostly cloudy, with a high near 56. Northeast wind around 15 mph, with gusts as high as 30 mph.  Chance of precipitation is 70%. New rainfall amounts of less than a tenth of an inch, except higher amounts possible in thunderstorms. "/></p><p class="short-desc">Showers<br/>Likely</p><p class="temp temp-high">High: 56 °F</p></div>

# %%
items[0].find(class_='period-name')
# Out:
# <p class="period-name">This<br/>Afternoon</p>

# %%
items[0].find(class_='period-name').get_text()
# Out:
# 'ThisAfternoon'

# %%
items[0].find(class_='short-desc').get_text()
# Out:
# 'ShowersLikely'

# %%
items[0].find(class_='temp').get_text()
# Out:
# 'High: 56 °F'

# %%
period_names = [item.find(class_='period-name').get_text() for item in items]

# %%
period_names = [item.find(class_='period-name').get_text() for item in items]
short_descriptions = [item.find(class_='short-desc').get_text() for item in items]
temperatures = [item.find(class_='temp').get_text() for item in items]
print(period_names)
print(short_descriptions)
print(temperatures)
# Out:
# ['ThisAfternoon', 'Tonight', 'Friday', 'FridayNight', 'Saturday', 'SaturdayNight', 'Sunday', 'SundayNight', 'MemorialDay']
# ['ShowersLikely', 'Showers andBreezy', 'ShowersLikely andBreezy', 'ChanceShowers andBreezy', 'Sunny', 'Mostly Clear', 'Sunny', 'Partly Cloudy', 'Partly Sunnythen SlightChanceShowers']
# ['High: 56 °F', 'Low: 50 °F', 'High: 52 °F', 'Low: 48 °F', 'High: 56 °F', 'Low: 50 °F', 'High: 60 °F', 'Low: 54 °F', 'High: 64 °F']

# %%
import pandas as pd
weather = pd.DataFrame(
    {
        'period': period_names,
        'short_descriptions': short_descriptions,
        'temperatures': temperatures,
    })

print(weather)
# Out:
#           period                    short_descriptions temperatures
# 0  ThisAfternoon                         ShowersLikely  High: 56 °F
# 1        Tonight                     Showers andBreezy   Low: 50 °F
# 2         Friday               ShowersLikely andBreezy  High: 52 °F
# 3    FridayNight               ChanceShowers andBreezy   Low: 48 °F
# 4       Saturday                                 Sunny  High: 56 °F
# 5  SaturdayNight                          Mostly Clear   Low: 50 °F
# 6         Sunday                                 Sunny  High: 60 °F
# 7    SundayNight                         Partly Cloudy   Low: 54 °F
# 8    MemorialDay  Partly Sunnythen SlightChanceShowers  High: 64 °F

# %%
weather.to_csv('weather_report.csv')
